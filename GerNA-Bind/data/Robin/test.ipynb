# %%
import json
with open("Robin_RNA.json") as rna_split:
    dico = json.load(rna_split)

# %%
dico.keys()
# Out:
# dict_keys(['train', 'eval', 'test'])

# %%
len(dico['train'])
# Out:
# 24967

# %%
len(dico['eval'])
# Out:
# 11049

# %%
len(dico['test'])
# Out:
# 10541

# %%
with open("Robin_mol.json") as mol_split:
    dico_mol = json.load(mol_split)

# %%
len(dico_mol['train'])
# Out:
# 27963

# %%
len(dico_mol['eval'])
# Out:
# 9306

# %%
len(dico_mol['test'])
# Out:
# 9288

# %%
import pandas as pd
df = pd.read_csv("Robin_Binding_Dataset.csv")

# %%
dico['train']
# Out:
# [5,
#  7,
#  9,
#  10,
#  25,
#  31,
#  33,
#  35,
#  36,
#  51,
#  57,
#  59,
#  61,
#  62,
#  77,
#  83,
#  85,
#  87,
#  88,
#  103,
#  109,
#  111,
#  113,
#  114,
#  129,
#  135,
#  137,
#  139,
#  140,
#  155,
#  161,
#  163,
#  165,
#  166,
#  181,
#  187,
#  189,
#  191,
#  192,
#  207,
#  213,
#  215,
#  217,
#  218,
#  233,
#  239,
#  241,
#  243,
#  244,
#  259,
#  265,
#  267,
#  269,
#  270,
#  285,
#  291,
#  293,
#  295,
#  296,
#  311,
#  317,
#  319,
#  321,
#  322,
#  337,
#  343,
#  345,
#  347,
#  348,
#  363,
#  369,
#  371,
#  373,
#  374,
#  389,
#  395,
#  397,
#  399,
#  400,
#  415,
#  421,
#  423,
#  425,
#  426,
#  441,
#  447,
#  449,
#  451,
#  452,
#  467,
#  473,
#  475,
#  477,
#  478,
#  493,
#  499,
#  501,
#  503,
#  504,
#  519,
#  525,
#  527,
#  529,
#  530,
#  545,
#  551,
#  553,
#  555,
#  556,
#  571,
#  577,
#  579,
#  581,
#  582,
#  597,
#  603,
#  605,
#  607,
#  608,
#  623,
#  629,
#  631,
#  633,
#  634,
#  649,
#  655,
#  657,
# ...

# %%
df[df['Name']=='5']
# Out:
# Empty DataFrame
# Columns: [Name, Smile, AKTIP, BCL_XL, BCL_XL_SS, ENE_A9, EWSR1, FGFR, Glutamine_RS, HBV, HIV_SL3, KLF6_mut, KLF6_wt, MALAT1, NRAS, PreQ1, Pre_miR_17, Pre_miR_21, Pre_miR_31, Pro_mut, Pro_wt, RRE2B_MeA, RRE2B, SAM_ll, TPP, TERRA, ZTP, Zika3PrimeUTR, Zika_NS5]
# Index: []
#
# [0 rows x 29 columns]
