# %%
import pandas as pd

df_aptamers_pos_old = pd.read_csv('Aptamers_positive_dataset_raw_final_v1.csv',sep='\t')
df_aptamers_neg_old = pd.read_csv('Aptamers_negative_dataset_raw_final_v1.csv',sep='\t')

df_aptamers_pos_new = pd.read_csv('Aptamers_pos_v1.csv',sep='\t')
df_aptamers_neg_new = pd.read_csv('Aptamers_neg_v1.csv',sep='\t')

# %%
df_aptamers_pos_old['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_1', 'ROBIN_RNA_14', 'ROBIN_RNA_24'], dtype=object)

# %%
df_aptamers_neg_old['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_1', 'ROBIN_RNA_14', 'ROBIN_RNA_24'], dtype=object)

# %%
df_aptamers_pos_new['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_1'], dtype=object)

# %%
df_aptamers_neg_new['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_1'], dtype=object)

# %%
df_mirna_pos_old = pd.read_csv('miRNA_positive_dataset_raw_final_v1.csv',sep='\t')
df_mirna_neg_old = pd.read_csv('miRNA_negative_dataset_raw_final_v1.csv',sep='\t')

df_mirna_pos_new = pd.read_csv('miRNA_pos_v1.csv',sep='\t')
df_mirna_neg_new = pd.read_csv('miRNA_neg_v1.csv',sep='\t')

# %%
df_mirna_pos_old['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_15', 'ROBIN_RNA_16', 'ROBIN_RNA_17'], dtype=object)

# %%
df_mirna_neg_old['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_15', 'ROBIN_RNA_16', 'ROBIN_RNA_17'], dtype=object)

# %%
df_mirna_pos_new['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_17'], dtype=object)

# %%
df_mirna_neg_new['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_17'], dtype=object)

# %%
df_Riboswitch_pos_old = pd.read_csv('Riboswitch_positive_dataset_raw_final_v1.csv',sep='\t')
df_Riboswitch_neg_old = pd.read_csv('Riboswitch_negative_dataset_raw_final_v1.csv',sep='\t')

df_Riboswitch_pos_new = pd.read_csv('Riboswitch_pos_v1.csv',sep='\t')
df_Riboswitch_neg_new = pd.read_csv('Riboswitch_neg_v1.csv',sep='\t')

# %%
df_Riboswitch_pos_old['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_8', 'ROBIN_RNA_18', 'ROBIN_RNA_23', 'ROBIN_RNA_25',
#        'ROBIN_RNA_28'], dtype=object)

# %%
df_Riboswitch_neg_old['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_8', 'ROBIN_RNA_18', 'ROBIN_RNA_23', 'ROBIN_RNA_25',
#        'ROBIN_RNA_28'], dtype=object)

# %%
df_Riboswitch_pos_new['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_18', 'ROBIN_RNA_28'], dtype=object)

# %%
df_Riboswitch_neg_new['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_18', 'ROBIN_RNA_25', 'ROBIN_RNA_28'], dtype=object)

# %%
df_Viral_RNA_pos_old = pd.read_csv('Viral_RNA_positive_dataset_raw_final_v1.csv',sep='\t')
df_Viral_RNA_neg_old = pd.read_csv('Viral_RNA_negative_dataset_raw_final_v1.csv',sep='\t')

df_Viral_RNA_pos_new = pd.read_csv('Viral_RNA_pos_v1.csv',sep='\t')
df_Viral_RNA_neg_new = pd.read_csv('Viral_RNA_neg_v1.csv',sep='\t')

# %%
df_Viral_RNA_pos_old['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_9', 'ROBIN_RNA_10', 'ROBIN_RNA_21', 'ROBIN_RNA_26',
#        'ROBIN_RNA_27'], dtype=object)

# %%
df_Viral_RNA_neg_old['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_9', 'ROBIN_RNA_10', 'ROBIN_RNA_21', 'ROBIN_RNA_26',
#        'ROBIN_RNA_27'], dtype=object)

# %%
df_Viral_RNA_pos_new['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_9', 'ROBIN_RNA_10', 'ROBIN_RNA_21', 'ROBIN_RNA_26',
#        'ROBIN_RNA_27'], dtype=object)

# %%
df_Viral_RNA_neg_new['Target_RNA_ID'].unique()
# Out:
# array(['ROBIN_RNA_9', 'ROBIN_RNA_10', 'ROBIN_RNA_21', 'ROBIN_RNA_26',
#        'ROBIN_RNA_27'], dtype=object)
