# %%
#Mapping the RNA and small molecule features to create the final dataset for model training

import sys
import csv
import pandas as pd
import random

def derangement(lst):
    shuffled = lst[:]
    while any(a == b for a, b in zip(lst, shuffled)):
        random.shuffle(shuffled)
    return dict(zip(lst, shuffled))

rna_feat = "./Riboswitch_output/RNA_features_v1.csv"
mol_feat = "./Riboswitch_output/Mol_features_Riboswitch.csv"
dataset_raw = "./data/Riboswitch_dataset_v1.csv"
outfile = "./Riboswitch_output/Final_dataset_Riboswitch_v4.csv"

# Ajout de la gestion de l'argument swapping
swapping = True
if len(sys.argv) > 5:
    swapping = sys.argv[5].lower() == "true"

rna_df = pd.read_csv(rna_feat, sep="\t", header=0)
rna_df.dropna(axis=1, how='any', subset=None, inplace=True)

mol_df = pd.read_csv(mol_feat, sep=",", header=0)
mol_df.dropna(axis=1, how='any', subset=None, inplace=True)

data_df = pd.read_csv(dataset_raw, sep="\t", header=0)

entries = list(data_df['Entry_ID'])

# Swapping conditionnel
if swapping:
    unique_rnas = list(data_df['Target_RNA_ID'].unique())
    rna_swap_dict = derangement(unique_rnas)
    rna_ids = list(data_df['Target_RNA_ID'].map(rna_swap_dict))
else:
    rna_ids = list(data_df['Target_RNA_ID'])

mol_ids = list(data_df['Molecule_ID'])

colnames = []
colnames.extend(list(rna_df.columns))
colnames.extend(list(mol_df.columns))
colnames.extend(["pKd"])
colnames.remove("name")
colnames.insert(2, "name")
final_df = pd.DataFrame(columns = colnames)
print(len(rna_df.index), len(mol_df.index), len(data_df.index))

for entry, rid, mid in zip(entries, rna_ids, mol_ids):
    try:
        data_point = pd.DataFrame(columns = colnames)
        rna_feat = rna_df.loc[rna_df['Target_RNA_ID'] == rid].to_dict('list')
        mol_feat = mol_df.loc[mol_df['name'] == mid].to_dict('list')
        # kd_val = {'pKd': [float(data_df.loc[data_df['Entry_ID'] == entry]['pKd'])]}
        kd_val = {'pKd': [float(data_df.loc[data_df['Entry_ID'] == entry]['pKd'].iloc[0])]}


        data_point = rna_feat
        data_point.update(mol_feat)
        data_point.update(kd_val)
        row = pd.DataFrame.from_dict(data_point)
        #print(data_point)
        final_df = pd.concat([final_df, row], ignore_index=True)  #Append the row to the final dataframe to create the dataset
        #print(final_df)
    except:
        print("Failed: ", entry, rid, mid)
        continue
# Out:
# 34 64 100
# /var/folders/mm/8mpvy80d0bv_54r_ffgrf4q00000gn/T/ipykernel_64281/1995327141.py:67: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_df = pd.concat([final_df, row], ignore_index=True)  #Append the row to the final dataframe to create the dataset
# Failed:  742 Target_191 Target_lig_504

# %%
final_df
# Out:
#    Target_RNA_ID                               Target_RNA_name  \
# 0     Target_416           Tetracycline riboswitch G51U mutant
# 1     Target_416           Tetracycline riboswitch G51U mutant
# 2     Target_416           Tetracycline riboswitch G51U mutant
# 3     Target_416           Tetracycline riboswitch G51U mutant
# 4     Target_416           Tetracycline riboswitch G51U mutant
# ..           ...                                           ...
# 94    Target_352         Fusibacterium ulcerans ZTP riboswitch
# 95    Target_189  165 ribD FMN Riboswitch Aptamer, B. subtilis
# 96    Target_189  165 ribD FMN Riboswitch Aptamer, B. subtilis
# 97    Target_189  165 ribD FMN Riboswitch Aptamer, B. subtilis
# 98    Target_189  165 ribD FMN Riboswitch Aptamer, B. subtilis
#
#                name        A        G        C        U     AA_x       AG  \
# 0    Target_lig_165  0.29577  0.22535  0.29577  0.18310  0.07042  0.05634
# 1    Target_lig_166  0.29577  0.22535  0.29577  0.18310  0.07042  0.05634
# 2    Target_lig_167  0.29577  0.22535  0.29577  0.18310  0.07042  0.05634
# 3    Target_lig_168  0.29577  0.22535  0.29577  0.18310  0.07042  0.05634
# 4    Target_lig_169  0.29577  0.22535  0.29577  0.18310  0.07042  0.05634
# ..              ...      ...      ...      ...      ...      ...      ...
# 94   Target_lig_496  0.32000  0.25333  0.20000  0.22667  0.08000  0.02667
# 95   Target_lig_663  0.28485  0.32727  0.18182  0.20606  0.06667  0.09091
# 96  Target_lig_1187  0.28485  0.32727  0.18182  0.20606  0.06667  0.09091
# 97   Target_lig_663  0.28485  0.32727  0.18182  0.20606  0.06667  0.09091
# 98   Target_lig_664  0.28485  0.32727  0.18182  0.20606  0.06667  0.09091
#
#          AC  ...      SRW10     TSRW10          MW       AMW  WPath  WPol  \
# 0   0.08451  ...   9.161465  53.745115  135.054495  9.003633    105    12
# 1   0.08451  ...   9.097508  53.600166  135.054495  9.003633    108    11
# 2   0.08451  ...   8.760767  37.736937  125.070145  7.816884     84     9
# 3   0.08451  ...   9.317849  55.364239  150.065394  8.827376    138    14
# 4   0.08451  ...   9.511555  56.191602  150.065394  8.827376    135    15
# ..      ...  ...        ...        ...         ...       ...    ...   ...
# 94  0.10667  ...  10.991157  77.031951  543.174061  7.987854   4392    83
# 95  0.03636  ...  10.113384  75.174897  382.157580  7.799134   2021    39
# 96  0.03636  ...  10.113384  75.174897  382.157580  7.799134   2021    39
# 97  0.03636  ...  10.113384  75.174897  382.157580  7.799134   2021    39
# 98  0.03636  ...  10.250582  81.100487  419.152829  8.218683   2740    43
#
#     Zagreb1  Zagreb2  mZagreb2       pKd
# 0      52.0     61.0  2.222222  6.397940
# 1      52.0     60.0  2.194444  5.789147
# 2      42.0     45.0  2.000000  4.698970
# 3      58.0     68.0  2.388889  7.698970
# 4      60.0     71.0  2.333333  8.397940
# ..      ...      ...       ...       ...
# 94    220.0    275.0  8.416667  4.978811
# 95    142.0    165.0  5.972222  7.795880
# 96    142.0    165.0  5.972222  5.000000
# 97    142.0    165.0  5.972222  8.180456
# 98    162.0    190.0  6.500000  9.000000
#
# [99 rows x 1554 columns]

# %%
mol_feat
# Out:
# {'name': ['Target_lig_664'],
#  'nAcid': [0],
#  'nBase': [1],
#  'nAromAtom': [22],
#  'nAromBond': [22],
#  'nAtom': [51],
#  'nHeavyAtom': [30],
#  'nSpiro': [0],
#  'nBridgehead': [0],
#  'nHetero': [9],
#  'nH': [21],
#  'nB': [0],
#  'nC': [21],
#  'nN': [7],
#  'nO': [1],
#  'nS': [1],
#  'nP': [0],
#  'nF': [0],
#  'nCl': [0],
#  'nBr': [0],
#  'nI': [0],
#  'nX': [0],
#  'ATS0dv': [408.44444444444446],
#  'ATS1dv': [425.6666666666667],
#  'ATS2dv': [593.6666666666667],
#  'ATS3dv': [539.3333333333333],
#  'ATS4dv': [542.3333333333334],
#  'ATS5dv': [447.6666666666667],
#  'ATS6dv': [444.6666666666667],
#  'ATS7dv': [349.66666666666663],
#  'ATS8dv': [357.6666666666667],
#  'ATS0d': [183.0],
#  'ATS1d': [233.0],
#  'ATS2d': [366.0],
#  'ATS3d': [397.0],
#  'ATS4d': [390.0],
#  'ATS5d': [381.0],
#  'ATS6d': [369.0],
#  'ATS7d': [331.0],
#  'ATS8d': [299.0],
#  'ATS0Z': [1440.0],
#  'ATS1Z': [1579.0],
#  'ATS2Z': [2331.0],
#  'ATS3Z': [2278.0],
#  'ATS4Z': [2246.0],
#  'ATS5Z': [2302.0],
#  'ATS6Z': [2131.0],
#  'ATS7Z': [1894.0],
#  'ATS8Z': [1715.0],
#  'ATS0m': [5708.0678290000005],
#  'ATS1m': [6074.341172],
#  'ATS2m': [8769.920256],
#  'ATS3m': [8241.901657],
#  'ATS4m': [8168.023604999999],
#  'ATS5m': [8420.818744],
#  'ATS6m': [7536.42246],
#  'ATS7m': [6666.778594999999],
#  'ATS8m': [6035.224156],
#  'ATS0v': [12062.980796068246],
#  'ATS1v': [15178.82313087768],
#  'ATS2v': [22399.592550352212],
#  'ATS3v': [23233.025387969512],
#  'ATS4v': [22757.37737495699],
#  'ATS5v': [23262.41008651893],
#  'ATS6v': [22150.768448811075],
#  'ATS7v': [19807.28679761673],
#  'ATS8v': [17968.204113580618],
#  'ATS0se': [392.94559699999985],
#  'ATS1se': [430.34453999999994],
#  'ATS2se': [745.0352859999998],
#  'ATS3se': [942.898328],
#  'ATS4se': [987.990128],
#  'ATS5se': [929.3116100000002],
#  'ATS6se': [976.137428],
#  'ATS7se': [873.2762079999999],
#  'ATS8se': [818.283084],
#  'ATS0pe': [321.37369999999993],
#  'ATS1pe': [362.3875],
#  'ATS2pe': [619.3646000000001],
#  'ATS3pe': [767.8348],
#  'ATS4pe': [799.6066],
#  'ATS5pe': [754.7299],
#  'ATS6pe': [791.4622999999999],
#  'ATS7pe': [702.9494],
#  'ATS8pe': [659.2722],
#  'ATS0are': [317.06789999999995],
#  'ATS1are': [354.254],
#  'ATS2are': [609.0564999999999],
#  'ATS3are': [756.3937000000001],
#  'ATS4are': [790.8105],
#  'ATS5are': [742.8927999999999],
#  'ATS6are': [782.3237999999999],
#  'ATS7are': [692.3836],
#  'ATS8are': [651.2848000000001],
#  'ATS0p': [85.42697500182898],
#  'ATS1p': [105.25519850000002],
#  'ATS2p': [160.359973134245],
#  'ATS3p': [172.78434431958402],
#  'ATS4p': [169.684051080621],
#  'ATS5p': [172.076311338131],
#  'ATS6p': [167.20723033243303],
#  'ATS7p': [154.106884896131],
#  'ATS8p': [138.97420849613098],
#  'ATS0i': [8317.41370307183],
#  'ATS1i': [8167.197615315299],
#  'ATS2i': [14914.382671083877],
#  'ATS3i': [19717.527330301346],
#  'ATS4i': [21441.607540445853],
#  'ATS5i': [19461.14961417168],
#  'ATS6i': [20653.617558518243],
#  'ATS7i': [18465.44819591715],
#  'ATS8i': [17595.101979370393],
#  'AATS0dv': [8.008714596949892],
#  'AATS1dv': [7.73939393939394],
#  'AATS2dv': [6.249122807017545],
#  'AATS3dv': [4.384823848238482],
#  'AATS4dv': [4.204134366925065],
#  'AATS5dv': [3.669398907103825],
#  'AATS6dv': [3.5291005291005293],
#  'AATS0d': [3.588235294117647],
#  'AATS1d': [4.236363636363636],
#  'AATS2d': [3.852631578947368],
#  'AATS3d': [3.227642276422764],
#  'AATS4d': [3.0232558139534884],
#  'AATS5d': [3.122950819672131],
#  'AATS6d': [2.9285714285714284],
#  'AATS0Z': [28.235294117647054],
#  'AATS1Z': [28.70909090909091],
#  'AATS2Z': [24.53684210526316],
#  'AATS3Z': [18.520325203252032],
#  'AATS4Z': [17.410852713178294],
#  'AATS5Z': [18.868852459016395],
#  'AATS6Z': [16.91269841269841],
#  'AATS0m': [111.92289860784317],
#  'AATS1m': [110.44256676363636],
#  'AATS2m': [92.3149500631579],
#  'AATS3m': [67.00733054471544],
#  'AATS4m': [63.31801244186046],
#  'AATS5m': [69.0231044590164],
#  'AATS6m': [59.81287666666667],
#  'AATS0v': [236.52903521702444],
#  'AATS1v': [275.9786023795942],
#  'AATS2v': [235.7851847405496],
#  'AATS3v': [188.8863852680448],
#  'AATS4v': [176.41377810044176],
#  'AATS5v': [190.67549251245023],
#  'AATS6v': [175.79974959373868],
#  'AATS0se': [7.704815627450977],
#  'AATS1se': [7.824446181818181],
#  'AATS2se': [7.84247669473684],
#  'AATS3se': [7.66584006504065],
#  'AATS4se': [7.658838201550387],
#  'AATS5se': [7.617308278688526],
#  'AATS6se': [7.747122444444444],
#  'AATS0pe': [6.301445098039214],
#  'AATS1pe': [6.588863636363636],
#  'AATS2pe': [6.5196273684210535],
#  'AATS3pe': [6.2425593495934955],
#  'AATS4pe': [6.198500775193798],
#  'AATS5pe': [6.186310655737706],
#  'AATS6pe': [6.2814468253968245],
#  'AATS0are': [6.217017647058823],
#  'AATS1are': [6.440981818181818],
#  'AATS2are': [6.411121052631578],
#  'AATS3are': [6.149542276422765],
#  'AATS4are': [6.130313953488373],
#  'AATS5are': [6.089285245901638],
#  'AATS6are': [6.208919047619046],
#  'AATS0p': [1.6750387255260584],
#  'AATS1p': [1.9137308818181824],
#  'AATS2p': [1.687999717202579],
#  'AATS3p': [1.4047507668258865],
#  'AATS4p': [1.3153802409350466],
#  'AATS5p': [1.410461568345336],
#  'AATS6p': [1.3270415105748652],
#  'AATS0i': [163.08654319748686],
#  'AATS1i': [148.4945020966418],
#  'AATS2i': [156.99350180088288],
#  'AATS3i': [160.3051002463524],
#  'AATS4i': [166.21401194144073],
#  'AATS5i': [159.51761978829248],
#  'AATS6i': [163.9175996707797],
#  'ATSC0dv': [193.63834422657953],
#  'ATSC1dv': [53.26365927634671],
#  'ATSC2dv': [13.486308684693936],
#  'ATSC3dv': [-0.9011918492887404],
#  'ATSC4dv': [30.790593361527623],
#  'ATSC5dv': [-83.09782562262379],
#  'ATSC6dv': [-111.66423170575418],
#  'ATSC7dv': [-62.816309966252305],
#  'ATSC8dv': [-44.7292494339784],
#  'ATSC0d': [27.686274509803926],
#  'ATSC1d': [6.103037293348709],
#  'ATSC2d': [-4.337178008458285],
#  'ATSC3d': [-1.4982698961937717],
#  'ATSC4d': [-2.4417531718569783],
#  'ATSC5d': [-6.582852748942715],
#  'ATSC6d': [-8.146482122260668],
#  'ATSC7d': [-6.3514033064206075],
#  'ATSC8d': [0.1091887735486355],
#  'ATSC0Z': [490.9803921568629],
#  'ATSC1Z': [40.09957708573629],
#  'ATSC2Z': [-16.51249519415606],
#  'ATSC3Z': [-92.01153402537486],
#  'ATSC4Z': [104.10841983852364],
#  'ATSC5Z': [68.67435601691659],
#  'ATSC6Z': [-196.12802768166097],
#  'ATSC7Z': [-158.9950019223376],
#  'ATSC8Z': [-111.56670511341792],
#  'ATSC0m': [2257.3595339215685],
#  'ATSC1m': [186.80316365321028],
#  'ATSC2m': [-76.97561083429451],
#  'ATSC3m': [-433.4193951441753],
#  'ATSC4m': [499.08968478662047],
#  'ATSC5m': [287.06784205036536],
#  'ATSC6m': [-911.0003257081894],
#  'ATSC7m': [-731.3658953721647],
#  'ATSC8m': [-511.8477258158401],
#  'ATSC0v': [2521.4570421450526],
#  'ATSC1v': [-51.93728133517702],
#  'ATSC2v': [-97.98772928616192],
#  'ATSC3v': [-735.8498747596454],
#  'ATSC4v': [949.9431837605634],
#  'ATSC5v': [-195.96889035363708],
#  'ATSC6v': [-561.0451434123316],
#  'ATSC7v': [-822.533232855303],
#  'ATSC8v': [-246.8602394039932],
#  'ATSC0se': [2.7515089803921557],
#  'ATSC1se': [-0.1613008415993876],
#  'ATSC2se': [0.5717929777008794],
#  'ATSC3se': [-0.6340775997693201],
#  'ATSC4se': [0.4921661476355246],
#  'ATSC5se': [-0.321601306036139],
#  'ATSC6se': [-1.2177026574394496],
#  'ATSC7se': [-0.3648480342176066],
#  'ATSC8se': [-0.9231400372933484],
#  'ATSC0pe': [4.869729411764703],
#  'ATSC1pe': [0.132340830449826],
#  'ATSC2pe': [0.7102314878892737],
#  'ATSC3pe': [-0.9554474048442904],
#  'ATSC4pe': [0.914907958477508],
#  'ATSC5pe': [-0.6358370242214533],
#  'ATSC6pe': [-2.5049491349480952],
#  'ATSC7pe': [-0.6452937716262966],
#  'ATSC8pe': [-1.6471754325259509],
#  'ATSC0are': [5.131098039215684],
#  'ATSC1are': [-0.0166076893502497],
#  'ATSC2are': [1.0061252210688196],
#  'ATSC3are': [-1.0889619377162625],
#  'ATSC4are': [0.9762931949250284],
#  'ATSC5are': [-1.0200972702806608],
#  'ATSC6are': [-2.4142892733564],
#  'ATSC7are': [-0.5380563629373318],
#  'ATSC8are': [-1.63410372933487],
#  'ATSC0p': [13.717491561232745],
#  'ATSC1p': [-0.6547608611297064],
#  'ATSC2p': [0.6177595734549431],
#  'ATSC3p': [-4.595513717322757],
#  'ATSC4p': [5.4160441343186845],
#  'ATSC5p': [-1.937555390192507],
#  'ATSC6p': [-0.6316300062124295],
#  'ATSC7p': [-5.182970913048602],
#  'ATSC8p': [0.1149967146058095],
#  'ATSC0i': [90.34443313787273],
#  'ATSC1i': [-29.911256580739327],
#  'ATSC2i': [22.702092788134728],
#  'ATSC3i': [-44.710140683957235],
#  'ATSC4i': [52.68687816167612],
#  'ATSC5i': [-27.65989919166133],
#  'ATSC6i': [17.06348308804444],
#  'ATSC7i': [-27.159636057588575],
#  'ATSC8i': [6.321629057349547],
#  'AATSC0dv': [3.79683027895254],
#  'AATSC1dv': [0.9684301686608492],
#  'AATSC2dv': [0.1419611440494098],
#  'AATSC3dv': [-0.0073267630023474],
#  'AATSC4dv': [0.2386867702444002],
#  'AATSC5dv': [-0.6811297182182278],
#  'AATSC6dv': [-0.8862240611567792],
#  'AATSC0d': [0.5428681276432142],
#  'AATSC1d': [0.110964314424522],
#  'AATSC2d': [-0.0456545053521924],
#  'AATSC3d': [-0.012181056066616],
#  'AATSC4d': [-0.018928319161682],
#  'AATSC5d': [-0.0539578094175632],
#  'AATSC6d': [-0.0646546200179418],
#  'AATSC0Z': [9.627066512879663],
#  'AATSC1Z': [0.7290832197406598],
#  'AATSC2Z': [-0.1738157388858532],
#  'AATSC3Z': [-0.74806125223882],
#  'AATSC4Z': [0.8070420142521213],
#  'AATSC5Z': [0.5629045575157098],
#  'AATSC6Z': [-1.5565716482671506],
#  'AATSC0m': [44.26195164552095],
#  'AATSC1m': [3.396421157331096],
#  'AATSC2m': [-0.8102695877294159],
#  'AATSC3m': [-3.523734919871344],
#  'AATSC4m': [3.868912285167601],
#  'AATSC5m': [2.3530150987734864],
#  'AATSC6m': [-7.23016131514436],
#  'AATSC0v': [49.440334159706914],
#  'AATSC1v': [-0.9443142060941276],
#  'AATSC2v': [-1.0314497819595991],
#  'AATSC3v': [-5.982519306988987],
#  'AATSC4v': [7.363900649306693],
#  'AATSC5v': [-1.6063023799478449],
#  'AATSC6v': [-4.4527392334312035],
#  'AATSC0se': [0.0539511564782775],
#  'AATSC1se': [-0.0029327425745343],
#  'AATSC2se': [0.0060188734494829],
#  'AATSC3se': [-0.0051551024371489],
#  'AATSC4se': [0.0038152414545389],
#  'AATSC5se': [-0.0026360762789847],
#  'AATSC6se': [-0.0096643068050749],
#  'AATSC0pe': [0.0954848904267588],
#  'AATSC1pe': [0.0024061969172695],
#  'AATSC2pe': [0.0074761209251502],
#  'AATSC3pe': [-0.0077678650800348],
#  'AATSC4pe': [0.0070923097556395],
#  'AATSC5pe': [-0.005211778887061],
#  'AATSC6pe': [-0.0198805486900642],
#  'AATSC0are': [0.1006097654748173],
#  'AATSC1are': [-0.0003019579881863],
#  'AATSC2are': [0.0105907918007244],
#  'AATSC3are': [-0.008853349087124],
#  'AATSC4are': [0.0075681643017444],
#  'AATSC5are': [-0.0083614530350873],
#  'AATSC6are': [-0.019161025979019],
#  'AATSC0p': [0.2689704227692694],
#  'AATSC1p': [-0.011904742929631],
#  'AATSC2p': [0.0065027323521572],
#  'AATSC3p': [-0.0373619001408354],
#  'AATSC4p': [0.0419848382505324],
#  'AATSC5p': [-0.0158816015589549],
#  'AATSC6p': [-0.0050129365572415],
#  'AATSC0i': [1.7714594732916218],
#  'AATSC1i': [-0.543841028740715],
#  'AATSC2i': [0.2389693977698392],
#  'AATSC3i': [-0.3634970787313596],
#  'AATSC4i': [0.4084254121060164],
#  'AATSC5i': [-0.2267204851775519],
#  'AATSC6i': [0.1354244689527336],
#  'MATS1dv': [0.2550628017347189],
#  'MATS2dv': [0.0373893836752096],
#  'MATS3dv': [-0.0019297051656385],
#  'MATS4dv': [0.0628647457769032],
#  'MATS5dv': [-0.1793943021351315],
#  'MATS6dv': [-0.2334115554412583],
#  'MATS1d': [0.2044038114859643],
#  'MATS2d': [-0.0840987028477709],
#  'MATS3d': [-0.0224383334484902],
#  'MATS4d': [-0.034867250807036],
#  'MATS5d': [-0.0993939534667719],
#  'MATS6d': [-0.1190982058545797],
#  'MATS1Z': [0.0757326459483009],
#  'MATS2Z': [-0.0180549016310744],
#  'MATS3Z': [-0.0777039663367879],
#  'MATS4Z': [0.0838305223270673],
#  'MATS5Z': [0.0584710365055255],
#  'MATS6Z': [-0.1616870150616157],
#  'MATS1m': [0.0767345548730405],
#  'MATS2m': [-0.0183062327259898],
#  'MATS3m': [-0.0796109251596438],
#  'MATS4m': [0.0874094372555556],
#  'MATS5m': [0.0531611239743333],
#  'MATS6m': [-0.1633493564189913],
#  'MATS1v': [-0.0191000773385493],
#  'MATS2v': [-0.0208625163945638],
#  'MATS3v': [-0.1210048315544081],
#  'MATS4v': [0.1489452038394221],
#  'MATS5v': [-0.0324897152749617],
#  'MATS6v': [-0.090062887096344],
#  'MATS1se': [-0.0543592161127284],
#  'MATS2se': [0.1115615279147228],
#  'MATS3se': [-0.095551287009474],
#  'MATS4se': [0.0707165833613795],
#  'MATS5se': [-0.0488604221124734],
#  'MATS6se': [-0.1791306699600805],
#  'MATS1pe': [0.0251997662301893],
#  'MATS2pe': [0.0782963764396291],
#  'MATS3pe': [-0.081351772467008],
#  'MATS4pe': [0.074276775350962],
#  'MATS5pe': [-0.0545822366634934],
#  'MATS6pe': [-0.2082062261496075],
#  'MATS1are': [-0.0030012791179991],
#  'MATS2are': [0.1052660420262613],
#  'MATS3are': [-0.0879969160582138],
#  'MATS4are': [0.0752229593819967],
#  'MATS5are': [-0.0831077678754778],
#  'MATS6are': [-0.1904489677377795],
#  'MATS1p': [-0.0442604164690749],
#  'MATS2p': [0.0241763844708513],
#  'MATS3p': [-0.138907095271533],
#  'MATS4p': [0.1560946286147909],
#  'MATS5p': [-0.0590459032463159],
#  'MATS6p': [-0.0186375011260689],
#  'MATS1i': [-0.3070016768321443],
#  'MATS2i': [0.1348997261144227],
#  'MATS3i': [-0.2051963842310943],
#  'MATS4i': [0.2305587106359844],
#  'MATS5i': [-0.1279851380151944],
#  'MATS6i': [0.076447963385296],
#  'GATS1dv': [0.5412046886506833],
#  'GATS2dv': [0.909786702354446],
#  'GATS3dv': [0.9699910539834472],
#  'GATS4dv': [0.9714692399472504],
#  'GATS5dv': [1.1355036630712252],
#  'GATS6dv': [1.2823001050105012],
#  'GATS1d': [0.7880504764357453],
#  'GATS2d': [1.2166393320411508],
#  'GATS3d': [1.0644821391556691],
#  'GATS4d': [1.1059687726464191],
#  'GATS5d': [1.1472217062183625],
#  'GATS6d': [1.1323013624713338],
#  'GATS1Z': [0.6998983444670345],
#  'GATS2Z': [0.9186774844459388],
#  'GATS3Z': [0.9935322995402476],
#  'GATS4Z': [0.8237749832825616],
#  'GATS5Z': [0.8096881055884353],
#  'GATS6Z': [1.1157623992088843],
#  'GATS1m': [0.6995033821188481],
#  'GATS2m': [0.9155478587149096],
#  'GATS3m': [0.9998046963718852],
#  'GATS4m': [0.8311680098809365],
#  'GATS5m': [0.8249622948628302],
#  'GATS6m': [1.121001186407608],
#  'GATS1v': [0.9129037663938964],
#  'GATS2v': [0.9227916885521844],
#  'GATS3v': [1.081994944957816],
#  'GATS4v': [0.8141191831640798],
#  'GATS5v': [1.0104197979810243],
#  'GATS6v': [1.038738928751777],
#  'GATS1se': [0.8196319043571217],
#  'GATS2se': [0.8257329324157073],
#  'GATS3se': [1.0424243052950457],
#  'GATS4se': [0.920549914479344],
#  'GATS5se': [0.9831555302088284],
#  'GATS6se': [1.4318555818422152],
#  'GATS1pe': [0.7272291315310981],
#  'GATS2pe': [0.8527221873472988],
#  'GATS3pe': [1.0389802836488529],
#  'GATS4pe': [0.9638605994694456],
#  'GATS5pe': [0.9895271586456582],
#  'GATS6pe': [1.3781362835966668],
#  'GATS1are': [0.7762382466703674],
#  'GATS2are': [0.8509977003375275],
#  'GATS3are': [1.0482629246781143],
#  'GATS4are': [0.9644565144557232],
#  'GATS5are': [1.0140752783056357],
#  'GATS6are': [1.3829073775440792],
#  'GATS1p': [0.9706842958683326],
#  'GATS2p': [0.9180623124188444],
#  'GATS3p': [1.0743858852406316],
#  'GATS4p': [0.7280029837485269],
#  'GATS5p': [0.976476473623162],
#  'GATS6p': [0.9461493484646694],
#  'GATS1i': [1.4534175187714329],
#  'GATS2i': [0.9838150182349192],
#  'GATS3i': [1.199133350999498],
#  'GATS4i': [0.7445580888109973],
#  'GATS5i': [1.0884321249002558],
#  'GATS6i': [0.8935813747944419],
#  'BalabanJ': [1.1123823741672336],
#  'BertzCT': [1169.5552615752044],
#  'nBonds': [55],
#  'nBondsO': [34],
#  'nBondsS': [32],
#  'nBondsD': [1],
#  'nBondsT': [0],
#  'nBondsA': [22],
#  'nBondsM': [23],
#  'nBondsKS': [45],
#  'nBondsKD': [10],
#  'C1SP1': [0],
#  'C2SP1': [0],
#  'C1SP2': [6],
#  'C2SP2': [7],
#  'C3SP2': [0],
#  'C1SP3': [3],
#  'C2SP3': [2],
#  'C3SP3': [1],
#  'C4SP3': [0],
#  'HybRatio': [0.2857142857142857],
#  'FCSP3': [0.2857142857142857],
#  'Xch-3d': [0.0],
#  'Xch-4d': [0.0],
#  'Xch-5d': [0.2621886974951644],
#  'Xch-6d': [0.48814483610392],
#  'Xch-7d': [0.6228736744336756],
#  'Xch-3dv': [0.0],
#  'Xch-4dv': [0.0],
#  'Xch-5dv': [0.1511844635310912],
#  'Xch-6dv': [0.1990946198240725],
#  'Xch-7dv': [0.2081049441153238],
#  'Xc-3d': [1.696923425058676],
#  'Xc-4d': [0.0],
#  'Xc-5d': [0.25],
#  'Xc-6d': [0.0],
#  'Xc-3dv': [0.8777972072924382],
#  'Xc-4dv': [0.0],
#  'Xc-5dv': [0.0928255275271575],
#  'Xc-6dv': [0.0],
#  'Xpc-4d': [3.792083601468444],
#  'Xpc-5d': [6.2864773771096365],
#  'Xpc-6d': [9.09348159612636],
#  'Xpc-4dv': [1.7412593790923834],
#  'Xpc-5dv': [2.408802419585401],
#  'Xpc-6dv': [2.919517844002874],
#  'Xp-1d': [14.742316078466889],
#  'Xp-2d': [13.24263543809773],
#  'Xp-3d': [11.137220758762991],
#  'Xp-4d': [9.717425464607183],
#  'Xp-5d': [7.433543501620409],
#  'Xp-6d': [5.112751573745726],
#  'Xp-7d': [3.9028100075323056],
#  'AXp-1d': [0.4335975317196143],
#  'AXp-2d': [0.28175820081059],
#  'AXp-3d': [0.179632592883274],
#  'AXp-4d': [0.1170774152362311],
#  'AXp-5d': [0.0750862979961657],
#  'AXp-6d': [0.0477827249882778],
#  'Xp-0dv': [17.1253113326842],
#  'Xp-1dv': [10.80168087322887],
#  'Xp-2dv': [8.336203263081062],
#  'Xp-3dv': [6.1229528570435905],
#  'Xp-4dv': [4.537142662382294],
#  'Xp-5dv': [2.907796405873415],
#  'Xp-6dv': [1.7373089892002358],
#  'Xp-7dv': [1.140893332105264],
#  'AXp-0dv': [0.5708437110894733],
#  'AXp-1dv': [0.3176964962714373],
#  'AXp-2dv': [0.1773660268740651],
#  'AXp-3dv': [0.0987573041458643],
#  'AXp-4dv': [0.0546643694262927],
#  'AXp-5dv': [0.0293716808674082],
#  'AXp-6dv': [0.0162365326093479],
#  'SZ': [36.666666666666664],
#  'Sm': [34.926900341353765],
#  'Sv': [33.89679075921027],
#  'Sse': [51.37181354697742],
#  'Spe': [49.8235294117647],
#  'Sare': [50.452000000000005],
#  'Sp': [36.212367065868264],
#  'Si': [57.52514258057068],
#  'MZ': [0.7189542483660131],
#  'Mm': [0.6848411831637993],
#  'Mv': [0.6646429560629464],
#  'Mse': [1.0072904617054397],
#  'Mpe': [0.9769319492502884],
#  'Mare': [0.9892549019607844],
#  'Mp': [0.7100464130562405],
#  'Mi': [1.1279439721680526],
#  'NsLi': [0],
#  'NssBe': [0],
#  'NssssBe': [0],
#  'NssBH': [0],
#  'NsssB': [0],
#  'NssssB': [0],
#  'NsCH3': [0],
#  'NdCH2': [0],
#  'NssCH2': [5],
#  'NtCH': [0],
#  'NdsCH': [0],
#  'NaaCH': [9],
#  'NsssCH': [1],
#  'NddC': [0],
#  'NtsC': [0],
#  'NdssC': [0],
#  'NaasC': [5],
#  'NaaaC': [0],
#  'NssssC': [0],
#  'NsNH3': [0],
#  'NsNH2': [0],
#  'NssNH2': [0],
#  'NdNH': [0],
#  'NssNH': [0],
#  'NaaNH': [1],
#  'NtN': [0],
#  'NsssNH': [0],
#  'NdsN': [0],
#  'NaaN': [4],
#  'NsssN': [1],
#  'NddsN': [0],
#  'NaasN': [1],
#  'NssssN': [0],
#  'NsOH': [0],
#  'NdO': [1],
#  'NssO': [0],
#  'NaaO': [0],
#  'NsF': [0],
#  'NsSiH3': [0],
#  'NssSiH2': [0],
#  'NsssSiH': [0],
#  'NssssSi': [0],
#  'NsPH2': [0],
#  'NssPH': [0],
#  'NsssP': [0],
#  'NdsssP': [0],
#  'NsssssP': [0],
#  'NsSH': [0],
#  'NdS': [0],
#  'NssS': [0],
#  'NaaS': [1],
#  'NdssS': [0],
#  'NddssS': [0],
#  'NsCl': [0],
#  'NsGeH3': [0],
#  'NssGeH2': [0],
#  'NsssGeH': [0],
#  'NssssGe': [0],
#  'NsAsH2': [0],
#  'NssAsH': [0],
#  'NsssAs': [0],
#  'NsssdAs': [0],
#  'NsssssAs': [0],
#  'NsSeH': [0],
#  'NdSe': [0],
#  'NssSe': [0],
#  'NaaSe': [0],
#  'NdssSe': [0],
#  'NddssSe': [0],
#  'NsBr': [0],
#  'NsSnH3': [0],
#  'NssSnH2': [0],
#  'NsssSnH': [0],
#  'NssssSn': [0],
#  'NsI': [0],
#  'NsPbH3': [0],
#  'NssPbH2': [0],
#  'NsssPbH': [0],
#  'NssssPb': [0],
#  'SsLi': [0],
#  'SssBe': [0],
#  'SssssBe': [0],
#  'SssBH': [0],
#  'SsssB': [0],
#  'SssssB': [0],
#  'SsCH3': [0.0],
#  'SdCH2': [0],
#  'SssCH2': [4.64930322495032],
#  'StCH': [0],
#  'SdsCH': [0.0],
#  'SaaCH': [16.492573246553825],
#  'SsssCH': [0.199911696415123],
#  'SddC': [0],
#  'StsC': [0.0],
#  'SdssC': [0.0],
#  'SaasC': [4.12667468829158],
#  'SaaaC': [0.0],
#  'SssssC': [0.0],
#  'SsNH3': [0.0],
#  'SsNH2': [0.0],
#  'SssNH2': [0],
#  'SdNH': [0],
#  'SssNH': [0.0],
#  'SaaNH': [2.964408465774184],
#  'StN': [0.0],
#  'SsssNH': [0],
#  'SdsN': [0.0],
#  'SaaN': [17.80358251996936],
#  'SsssN': [2.365577522675737],
#  'SddsN': [0],
#  'SaasN': [1.83363323440028],
#  'SssssN': [0],
#  'SsOH': [0.0],
#  'SdO': [12.229866060484678],
#  'SssO': [0.0],
#  'SaaO': [0],
#  'SsF': [0.0],
#  'SsSiH3': [0],
#  'SssSiH2': [0],
#  'SsssSiH': [0],
#  'SssssSi': [0],
#  'SsPH2': [0],
#  'SssPH': [0],
#  'SsssP': [0],
#  'SdsssP': [0.0],
#  'SsssssP': [0],
#  'SsSH': [0],
#  'SdS': [0],
#  'SssS': [0.0],
#  'SaaS': [1.596388204531372],
#  'SdssS': [0],
#  'SddssS': [0.0],
#  'SsCl': [0.0],
#  'SsGeH3': [0],
#  'SssGeH2': [0],
#  'SsssGeH': [0],
#  'SssssGe': [0],
#  'SsAsH2': [0],
#  'SssAsH': [0],
#  'SsssAs': [0],
#  'SsssdAs': [0],
#  'SsssssAs': [0],
#  'SsSeH': [0],
#  'SdSe': [0],
#  'SssSe': [0],
#  'SaaSe': [0],
#  'SdssSe': [0],
#  'SddssSe': [0],
#  'SsBr': [0],
#  'SsSnH3': [0],
#  'SssSnH2': [0],
#  'SsssSnH': [0],
#  'SssssSn': [0],
#  'SsI': [0],
#  'SsPbH3': [0],
#  'SssPbH2': [0],
#  'SsssPbH': [0],
#  'SssssPb': [0],
#  'ECIndex': [838],
#  'fragCpx': [286.09],
#  'fMF': [0.5686274509803921],
#  'GeomDiameter': [15.199286844125286],
#  'GeomRadius': [8.70538099625743],
#  'GeomShapeIndex': [0.7459645764682419],
#  'GeomPetitjeanIndex': [0.4272506936980291],
#  'nHBAcc': [8],
#  'nHBDon': [1],
#  'IC0': [1.6698995339104925],
#  'IC1': [3.974718031814807],
#  'IC2': [5.162621420402868],
#  'IC3': [5.476346910598947],
#  'IC4': [5.476346910598947],
#  'IC5': [5.476346910598947],
#  'TIC0': [85.16487622943511],
#  'TIC1': [202.7106196225552],
#  'TIC2': [263.29369244054624],
#  'TIC3': [279.2936924405463],
#  'TIC4': [279.2936924405463],
#  'TIC5': [279.2936924405463],
#  'SIC0': [0.2943889841184063],
#  'SIC1': [0.7007087431199868],
#  'SIC2': [0.9101259354095896],
#  'SIC3': [0.9654330520806116],
#  'SIC4': [0.9654330520806116],
#  'SIC5': [0.9654330520806116],
#  'BIC0': [0.2772828870229289],
#  'BIC1': [0.6599925735548938],
#  'BIC2': [0.8572411351618778],
#  'BIC3': [0.909334514366878],
#  'BIC4': [0.909334514366878],
#  'BIC5': [0.909334514366878],
#  'CIC0': [4.002525808061003],
#  'CIC1': [1.6977073101566875],
#  'CIC2': [0.5098039215686274],
#  'CIC3': [0.1960784313725483],
#  'CIC4': [0.1960784313725483],
#  'CIC5': [0.1960784313725483],
#  'MIC0': [17.71663355075909],
#  'MIC1': [40.320747206103825],
#  'MIC2': [46.14615382180058],
#  'MIC3': [46.46238911591823],
#  'MIC4': [46.46238911591823],
#  'MIC5': [46.46238911591823],
#  'ZMIC0': [99.42255899579912],
#  'ZMIC1': [42.392086236381765],
#  'ZMIC2': [26.735014475071484],
#  'ZMIC3': [25.189369189283216],
#  'ZMIC4': [25.189369189283216],
#  'ZMIC5': [25.189369189283216],
#  'Kier1': [21.825259515570934],
#  'Kier2': [10.29244001810774],
#  'Kier3': [5.506763787721124],
#  'Lipinski': [1],
#  'GhoseFilter': [1],
#  'FilterItLogS': [-5.088952822365648],
#  'VMcGowan': [301.53000000000077],
#  'LabuteASA': [176.8655981235402],
#  'PEOE_VSA1': [4.9839785209472085],
#  'PEOE_VSA2': [14.261546562713654],
#  'PEOE_VSA3': [19.93591408378883],
#  'PEOE_VSA4': [0.0],
#  'PEOE_VSA5': [11.336785877934735],
#  'PEOE_VSA6': [6.06636706846161],
#  'PEOE_VSA7': [36.89919655915373],
#  'PEOE_VSA8': [43.66431664128738],
#  'PEOE_VSA9': [16.26500318339822],
#  'PEOE_VSA10': [12.151724572764468],
#  'PEOE_VSA11': [0.0],
#  'PEOE_VSA12': [5.948339280986494],
#  'PEOE_VSA13': [5.559266895052007],
#  'SMR_VSA1': [0.0],
#  'SMR_VSA2': [0.0],
#  'SMR_VSA3': [34.386901983377875],
#  'SMR_VSA4': [0.0],
#  'SMR_VSA5': [25.304305697925987],
#  'SMR_VSA6': [13.08951281182515],
#  'SMR_VSA7': [76.43551840588835],
#  'SMR_VSA8': [0.0],
#  'SMR_VSA9': [16.519414469536255],
#  'SlogP_VSA1': [5.559266895052007],
#  'SlogP_VSA2': [47.476414795203034],
#  'SlogP_VSA3': [6.544756405912575],
#  'SlogP_VSA4': [0.0],
#  'SlogP_VSA5': [30.2778817848618],
#  'SlogP_VSA6': [59.357919017987946],
#  'SlogP_VSA7': [0.0],
#  'SlogP_VSA8': [16.519414469536255],
#  'SlogP_VSA9': [0.0],
#  'SlogP_VSA10': [0.0],
#  'SlogP_VSA11': [0.0],
#  'EState_VSA1': [0.0],
#  'EState_VSA2': [11.4771729412134],
#  'EState_VSA3': [5.948339280986494],
#  'EState_VSA4': [54.565320144987886],
#  'EState_VSA5': [0.0],
#  'EState_VSA6': [42.19052723284865],
#  'EState_VSA7': [28.27674012679357],
#  'EState_VSA8': [24.83582381463931],
#  'EState_VSA9': [4.9839785209472085],
#  'EState_VSA10': [4.794537184071822],
#  'VSA_EState1': [1.83363323440028],
#  'VSA_EState2': [36.380736631758595],
#  'VSA_EState3': [1.99983610715483],
#  'VSA_EState4': [1.6263863370968767],
#  'VSA_EState5': [1.587645787375398],
#  'VSA_EState6': [7.343171503318067],
#  'VSA_EState7': [9.218753461476362],
#  'VSA_EState8': [2.5801153995548836],
#  'VSA_EState9': [0.0],
#  'MDEC-33': [5.289642161214395],
#  'MOMI-X': [9353.636200082594],
#  'MOMI-Y': [8504.970149364326],
#  'MOMI-Z': [1939.7263632834847],
#  'PBF': [1.1502765161916804],
#  'MPC2': [47],
#  'MPC3': [62],
#  'MPC4': [83],
#  'MPC5': [99],
#  'MPC6': [107],
#  'MPC7': [125],
#  'MPC8': [137],
#  'MPC9': [153],
#  'MPC10': [163],
#  'TMPC10': [1040],
#  'piPC1': [3.8501476017100584],
#  'piPC2': [4.448516375942715],
#  'piPC3': [5.012300573415317],
#  'piPC4': [5.607179793264784],
#  'piPC5': [6.008813185442595],
#  'piPC6': [6.2959576441185146],
#  'piPC7': [6.652863029353347],
#  'piPC8': [6.933483940054737],
#  'piPC9': [7.1598627954632175],
#  'piPC10': [7.338167032452266],
#  'TpiPC10': [8.724400431592093],
#  'apol': [60.47465299999999],
#  'bpol': [32.945347],
#  'nRing': [5],
#  'n3Ring': [0],
#  'n4Ring': [0],
#  'n5Ring': [2],
#  'n6Ring': [3],
#  'n7Ring': [0],
#  'n8Ring': [0],
#  'n9Ring': [0],
#  'n10Ring': [0],
#  'n11Ring': [0],
#  'n12Ring': [0],
#  'nG12Ring': [0],
#  'nHRing': [5],
#  'n3HRing': [0],
#  'n4HRing': [0],
#  'n5HRing': [2],
#  'n6HRing': [3],
#  'n7HRing': [0],
#  'n8HRing': [0],
#  'n9HRing': [0],
#  'n10HRing': [0],
#  'n11HRing': [0],
#  'n12HRing': [0],
#  'nG12HRing': [0],
#  'naRing': [4],
#  'n3aRing': [0],
#  'n4aRing': [0],
#  'n5aRing': [2],
#  'n6aRing': [2],
#  'n7aRing': [0],
#  'n8aRing': [0],
#  'n9aRing': [0],
#  'n10aRing': [0],
#  'n11aRing': [0],
#  'n12aRing': [0],
#  'nG12aRing': [0],
#  'naHRing': [4],
#  'n3aHRing': [0],
#  'n4aHRing': [0],
#  'n5aHRing': [2],
#  'n6aHRing': [2],
#  'n7aHRing': [0],
#  'n8aHRing': [0],
#  'n9aHRing': [0],
#  'n10aHRing': [0],
#  'n11aHRing': [0],
#  'n12aHRing': [0],
#  'nG12aHRing': [0],
#  'nARing': [1],
#  'n3ARing': [0],
#  'n4ARing': [0],
#  'n5ARing': [0],
#  'n6ARing': [1],
#  'n7ARing': [0],
#  'n8ARing': [0],
#  'n9ARing': [0],
#  'n10ARing': [0],
#  'n11ARing': [0],
#  'n12ARing': [0],
#  'nG12ARing': [0],
#  'nAHRing': [1],
#  'n3AHRing': [0],
#  'n4AHRing': [0],
#  'n5AHRing': [0],
#  'n6AHRing': [1],
#  'n7AHRing': [0],
#  'n8AHRing': [0],
#  'n9AHRing': [0],
#  'n10AHRing': [0],
#  'n11AHRing': [0],
#  'n12AHRing': [0],
#  'nG12AHRing': [0],
#  'nFRing': [0],
#  'n4FRing': [0],
#  'n5FRing': [0],
#  'n6FRing': [0],
#  'n7FRing': [0],
#  'n8FRing': [0],
#  'n9FRing': [0],
#  'n10FRing': [0],
#  'n11FRing': [0],
#  'n12FRing': [0],
#  'nG12FRing': [0],
#  'nFHRing': [0],
#  'n4FHRing': [0],
#  'n5FHRing': [0],
#  'n6FHRing': [0],
#  'n7FHRing': [0],
#  'n8FHRing': [0],
#  'n9FHRing': [0],
#  'n10FHRing': [0],
#  'n11FHRing': [0],
#  'n12FHRing': [0],
#  'nG12FHRing': [0],
#  'nFaRing': [0],
#  'n4FaRing': [0],
#  'n5FaRing': [0],
#  'n6FaRing': [0],
#  'n7FaRing': [0],
#  'n8FaRing': [0],
#  'n9FaRing': [0],
#  'n10FaRing': [0],
#  'n11FaRing': [0],
#  'n12FaRing': [0],
#  'nG12FaRing': [0],
#  'nFaHRing': [0],
#  'n4FaHRing': [0],
#  'n5FaHRing': [0],
#  'n6FaHRing': [0],
#  'n7FaHRing': [0],
#  'n8FaHRing': [0],
#  'n9FaHRing': [0],
#  'n10FaHRing': [0],
#  'n11FaHRing': [0],
#  'n12FaHRing': [0],
#  'nG12FaHRing': [0],
#  'nFARing': [0],
#  'n4FARing': [0],
#  'n5FARing': [0],
#  'n6FARing': [0],
#  'n7FARing': [0],
#  'n8FARing': [0],
#  'n9FARing': [0],
#  'n10FARing': [0],
#  'n11FARing': [0],
#  'n12FARing': [0],
#  'nG12FARing': [0],
#  'nFAHRing': [0],
#  'n4FAHRing': [0],
#  'n5FAHRing': [0],
#  'n6FAHRing': [0],
#  'n7FAHRing': [0],
#  'n8FAHRing': [0],
#  'n9FAHRing': [0],
#  'n10FAHRing': [0],
#  'n11FAHRing': [0],
#  'n12FAHRing': [0],
#  'nG12FAHRing': [0],
#  'nRot': [5],
#  'RotRatio': [0.1470588235294117],
#  'SLogP': [2.853700000000001],
#  'SMR': [114.57670000000005],
#  'TopoPSA(NO)': [92.59],
#  'TopoPSA': [120.83],
#  'GGI1': [5.5],
#  'GGI2': [2.4444444444444455],
#  'GGI3': [1.3749999999999998],
#  'GGI4': [1.2866666666666666],
#  'GGI5': [0.8891666666666667],
#  'GGI6': [0.5289795918367347],
#  'GGI7': [0.21531320861678],
#  ...}

# %%
data_df[]
# Out:
#     Entry_ID                                             SMILES  \
# 0        221                               C1=NC2=NC=NC(=C2N1)N
# 1        222                             C1=C2C(=NC(=N1)N)N=CN2
# 2        223                                 C1=C(N=C(N=C1N)N)N
# 3        224                            C1=NC2=NC(=NC(=C2N1)N)N
# 4        225                            C1=NC(=NC2(C1=NC=N2)N)N
# ..       ...                                                ...
# 95      2284  C[C@H]1[C@H]([C@H](C[C@@H](O1)O[C@H]2C[C@@](CC...
# 96      2320  CNC1=NC=C(C=N1)CN2CCC[C@@H](C2)C3=NC(=CC(=O)N3...
# 97      2321    CNc1ncc(cn1)CN1CCC[C@H](C1)c1nc(O)cc(n1)c1cccs1
# 98      2322  CNC1=NC=C(C=N1)CN2CCC[C@@H](C2)C3=NC(=CC(=O)N3...
# 99      2323  C1C[C@@H](CN(C1)CC2=CN(C=N2)C3=NC=CC=N3)C4=NC(...
#
#                                   Target_RNA_sequence  \
# 0   GGACAUAUAAUCGCGUGGAUAUGGCACGCAAGUUUCUACCGGGCAC...
# 1   GGACAUAUAAUCGCGUGGAUAUGGCACGCAAGUUUCUACCGGGCAC...
# 2   GGACAUAUAAUCGCGUGGAUAUGGCACGCAAGUUUCUACCGGGCAC...
# 3   GGACAUAUAAUCGCGUGGAUAUGGCACGCAAGUUUCUACCGGGCAC...
# 4   GGACAUAUAAUCGCGUGGAUAUGGCACGCAAGUUUCUACCGGGCAC...
# ..                                                ...
# 95  GGGCCUAAAACAUACCAGAUCGCCACCCGCGCUUUAAUCUGGAGAG...
# 96                GGCGUGUAGGAUAUGCUUCGGCAGAAGGACACGCC
# 97                GGCGUGUAGGAUAUGCUUCGGCAGAAGGACACGCC
# 98                GGCGUGUAGGAUAUGCUUCGGCAGAAGGACACGCC
# 99                GGCGUGUAGGAUAUGCUUCGGCAGAAGGACACGCC
#
#                Molecule_name      Molecule_ID  \
# 0                    Adenine   Target_lig_165
# 1              2-aminopurine   Target_lig_166
# 2   2,4,6-triaminopyrimidine   Target_lig_167
# 3         2,6- diaminopurine   Target_lig_168
# 4          2,4-diaminopurine   Target_lig_169
# ..                       ...              ...
# 95                       dox   Target_lig_496
# 96                   Ribocil   Target_lig_663
# 97                 Ribocil-A  Target_lig_1187
# 98                 Ribocil-B   Target_lig_663
# 99                 Ribocil-C   Target_lig_664
#
#                         Target_RNA_name Target_RNA_ID       pKd
# 0                    ADENINE RIBOSWITCH     Target_69  6.397940
# 1                    ADENINE RIBOSWITCH     Target_69  5.789147
# 2                    ADENINE RIBOSWITCH     Target_69  4.698970
# 3                    ADENINE RIBOSWITCH     Target_69  7.698970
# 4                    ADENINE RIBOSWITCH     Target_69  8.397940
# ..                                  ...           ...       ...
# 95  Tetracycline riboswitch A50U mutant    Target_415  4.978811
# 96               FMN RIBOSWITCH APTAMER     Target_36  7.795880
# 97               FMN RIBOSWITCH APTAMER     Target_36  5.000000
# 98               FMN RIBOSWITCH APTAMER     Target_36  8.180456
# 99               FMN RIBOSWITCH APTAMER     Target_36  9.000000
#
# [100 rows x 8 columns]

# %%
mid
# Out:
# 'Target_lig_504'

# %%
data_df['Molecule_ID'].unique()
# Out:
# array(['Target_lig_165', 'Target_lig_166', 'Target_lig_167',
#        'Target_lig_168', 'Target_lig_169', 'Target_lig_173',
#        'Target_lig_162', 'Target_lig_248', 'Target_lig_249',
#        'Target_lig_250', 'Target_lig_314', 'Target_lig_318',
#        'Target_lig_68', 'Target_lig_331', 'Target_lig_1248',
#        'Target_lig_31', 'Target_lig_502', 'Target_lig_503',
#        'Target_lig_504', 'Target_lig_70', 'Target_lig_505',
#        'Target_lig_57', 'Target_lig_506', 'Target_lig_507',
#        'Target_lig_508', 'Target_lig_509', 'Target_lig_662',
#        'Target_lig_663', 'Target_lig_664', 'Target_lig_1254',
#        'Target_lig_665', 'Target_lig_1255', 'Target_lig_666',
#        'Target_lig_667', 'Target_lig_668', 'Target_lig_336',
#        'Target_lig_669', 'Target_lig_714', 'Target_lig_1260',
#        'Target_lig_1261', 'Target_lig_1044', 'Target_lig_1045',
#        'Target_lig_1046', 'Target_lig_1047', 'Target_lig_1048',
#        'Target_lig_1049', 'Target_lig_1050', 'Target_lig_1051',
#        'Target_lig_1121', 'Target_lig_1122', 'Target_lig_1123',
#        'Target_lig_1153', 'Target_lig_1154', 'Target_lig_74',
#        'Target_lig_1164', 'Target_lig_1165', 'Target_lig_1166',
#        'Target_lig_1167', 'Target_lig_1168', 'Target_lig_1169',
#        'Target_lig_496', 'Target_lig_1171', 'Target_lig_18',
#        'Target_lig_1173', 'Target_lig_1187'], dtype=object)

# %%
mol_df['name'].unique()
# Out:
# array(['Target_lig_165', 'Target_lig_166', 'Target_lig_167',
#        'Target_lig_168', 'Target_lig_169', 'Target_lig_173',
#        'Target_lig_162', 'Target_lig_248', 'Target_lig_249',
#        'Target_lig_250', 'Target_lig_314', 'Target_lig_318',
#        'Target_lig_68', 'Target_lig_331', 'Target_lig_1248',
#        'Target_lig_31', 'Target_lig_502', 'Target_lig_503',
#        'Target_lig_70', 'Target_lig_505', 'Target_lig_57',
#        'Target_lig_506', 'Target_lig_507', 'Target_lig_508',
#        'Target_lig_509', 'Target_lig_662', 'Target_lig_663',
#        'Target_lig_664', 'Target_lig_1254', 'Target_lig_665',
#        'Target_lig_1255', 'Target_lig_666', 'Target_lig_667',
#        'Target_lig_668', 'Target_lig_336', 'Target_lig_669',
#        'Target_lig_714', 'Target_lig_1260', 'Target_lig_1261',
#        'Target_lig_1044', 'Target_lig_1045', 'Target_lig_1046',
#        'Target_lig_1047', 'Target_lig_1048', 'Target_lig_1049',
#        'Target_lig_1050', 'Target_lig_1051', 'Target_lig_1121',
#        'Target_lig_1122', 'Target_lig_1123', 'Target_lig_1153',
#        'Target_lig_1154', 'Target_lig_74', 'Target_lig_1164',
#        'Target_lig_1165', 'Target_lig_1166', 'Target_lig_1167',
#        'Target_lig_1168', 'Target_lig_1169', 'Target_lig_496',
#        'Target_lig_1171', 'Target_lig_18', 'Target_lig_1173',
#        'Target_lig_1187'], dtype=object)
