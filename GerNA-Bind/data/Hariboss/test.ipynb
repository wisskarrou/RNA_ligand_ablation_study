# %%
import json
with open("data_split.json") as f:
    dico = json.load(f)

# %%
len(dico['train'])
# Out:
# 318

# %%
len(dico['valid'])
# Out:
# 19

# %%
len(dico['test'])
# Out:
# 22

# %%
dico.keys()
# Out:
# dict_keys(['train', 'valid', 'test'])
